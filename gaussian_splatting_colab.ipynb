# %% [markdown]
# <a href="https://colab.research.google.com/github/akashkumarsl/3DGaussianResearch/blob/main/gaussian_splatting_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile

# %cd /content/gaussian-splatting
# !pip install -q /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install -q /content/gaussian-splatting/submodules/simple-knn

# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# !unzip tandt_db.zip

# !python train.py -s /content/gaussian-splatting/tandt/train

# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/GaussianViewTest.zip
# !unzip GaussianViewTest.zip
# !python render.py -m /content/gaussian-splatting/GaussianViewTest/model
# !ffmpeg -framerate 3 -i /content/gaussian-splatting/GaussianViewTest/model/train/ours_30000/renders/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/renders.mp4
# !ffmpeg -framerate 3 -i /content/gaussian-splatting/GaussianViewTest/model/train/ours_30000/gt/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/gt.mp4 -y
# Out:
# /content
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 842.00 KiB/s, done.
# Resolving deltas: 100% (344/344), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 3293 (delta 171), reused 280 (delta 148), pack-reused 2971 (from 1)
# ...

# %%
# !nvidia-smi
# Out:
# Tue Mar 10 18:52:45 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
pip install kornia
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 112.0 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/PeizhiYan/gaussian-dejavu.git
# Out:
# Cloning into 'gaussian-dejavu'...
# remote: Enumerating objects: 560, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 560 (delta 116), reused 116 (delta 48), pack-reused 362 (from 1)
# Receiving objects: 100% (560/560), 212.52 MiB | 13.52 MiB/s, done.
# Resolving deltas: 100% (282/282), done.

# %%
# %cd gaussian-dejavu
# Out:
# /content/gaussian-splatting/gaussian-dejavu

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/NVlabs/nvdiffrast (to revision v0.3.1) to /tmp/pip-req-build-94mf6yhn
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/nvdiffrast /tmp/pip-req-build-94mf6yhn
#   Running command git checkout -q c5caf7bdb8a2448acc491a9faa47753972edd380
#   Resolved https://github.com/NVlabs/nvdiffrast to commit c5caf7bdb8a2448acc491a9faa47753972edd380
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/pytorch3d.git (to revision V0.7.8) to /tmp/pip-req-build-10nz9493
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/pytorch3d.git /tmp/pip-req-build-10nz9493
#   Running command git checkout -q 75ebeeaea0908c5527e7b1e305fbc7681382db47
#   Resolved https://github.com/facebookresearch/pytorch3d.git to commit 75ebeeaea0908c5527e7b1e305fbc7681382db47
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install numpy==1.26.4

# %%
import torch
import numpy
import nvdiffrast
import pytorch3d
import diff_gaussian_rasterization

print("All modules loaded")
print("GPU:", torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6009/2369995761.py in <cell line: 0>()
#       1 import torch
#       2 import numpy
# ----> 3 import nvdiffrast
#       4 import pytorch3d
#       5 import diff_gaussian_rasterization
#
# ModuleNotFoundError: No module named 'nvdiffrast'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %cd /content/gaussian-splatting/gaussian-dejavu
# !pip install -r requirements.txt
# Out:
# /content/gaussian-splatting/gaussian-dejavu
# ...
#   Cloning https://github.com/NVlabs/nvdiffrast (to revision v0.3.1) to /tmp/pip-req-build-jcdggzng
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/nvdiffrast /tmp/pip-req-build-jcdggzng
#   Running command git checkout -q c5caf7bdb8a2448acc491a9faa47753972edd380
#   Resolved https://github.com/NVlabs/nvdiffrast to commit c5caf7bdb8a2448acc491a9faa47753972edd380
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/pytorch3d.git (to revision V0.7.8) to /tmp/pip-req-build-1unhxrzm
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/pytorch3d.git /tmp/pip-req-build-1unhxrzm
#   Running command git checkout -q 75ebeeaea0908c5527e7b1e305fbc7681382db47
#   Resolved https://github.com/facebookresearch/pytorch3d.git to commit 75ebeeaea0908c5527e7b1e305fbc7681382db47
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd /content/gaussian-splatting/gaussian-dejavu
# !sed -i '/numpy==1.22.3/d' requirements.txt
# !pip install -r requirements.txt
# Out:
# /content/gaussian-splatting/gaussian-dejavu
# ...
#   Cloning https://github.com/NVlabs/nvdiffrast (to revision v0.3.1) to /tmp/pip-req-build-2antu829
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/nvdiffrast /tmp/pip-req-build-2antu829
#   Running command git checkout -q c5caf7bdb8a2448acc491a9faa47753972edd380
#   Resolved https://github.com/NVlabs/nvdiffrast to commit c5caf7bdb8a2448acc491a9faa47753972edd380
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/pytorch3d.git (to revision V0.7.8) to /tmp/pip-req-build-kevdgr15
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/pytorch3d.git /tmp/pip-req-build-kevdgr15
#   Running command git checkout -q 75ebeeaea0908c5527e7b1e305fbc7681382db47
#   Resolved https://github.com/facebookresearch/pytorch3d.git to commit 75ebeeaea0908c5527e7b1e305fbc7681382db47
#   Preparing metadata (setup.py) ... done
# ...
